# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mssql+pyodbc://localhost\\SQLEXPRESS/DecodelabsDB?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes")
df = pd.read_sql("SELECT * FROM Orders", engine)

# %%
df.head()
# Out:
#   OrderID        Date  Year  Month CustomerID  Product  Quantity  UnitPrice  \
# 0  200000  2023-01-04  2023      1      72649  Monitor         5     570.62
# 1  200001  2024-08-23  2024      8      75739    Phone         2     151.35
# 2  200002  2024-02-27  2024      2      81728   Tablet         5     550.68
# 3  200003  2023-10-15  2023     10      33540    Chair         1     273.19
# 4  200004  2025-05-08  2025      5      81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0             928    Debit Card     Shipped       37947903            7
# 1             823        Online     Shipped       91186779            3
# 2             512   Credit Card   Cancelled       42903982            8
# 3             275    Debit Card    Returned       62788070            5
# 4             668        Online   Delivered       29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# ...

# %%
# Write pandas dataframe back to SQL
df.to_sql('Orders', con=engine, if_exists='replace', index=False)
# Out:
# 42
